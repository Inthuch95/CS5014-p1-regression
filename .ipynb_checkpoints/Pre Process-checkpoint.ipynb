# %%
import pandas as pd

energy = pd.read_csv("energydata_complete.csv")
energy.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4    ...             T9   RH_9     T_out  \
# 0  19.79  44.730000  19.000000    ...      17.033333  45.53  6.600000
# 1  19.79  44.790000  19.000000    ...      17.066667  45.56  6.483333
# 2  19.79  44.933333  18.926667    ...      17.000000  45.50  6.366667
# 3  19.79  45.000000  18.890000    ...      17.000000  45.40  6.250000
# 4  19.79  45.000000  18.890000    ...      17.000000  45.40  6.133333
#
# ...

# %%
from datetime import datetime, timedelta
import numpy as np

def nsm(dt_obj):
    """Get the number of seconds until midnight."""
    tomorrow = dt_obj + timedelta(1)
    midnight = datetime(year=tomorrow.year, month=tomorrow.month, 
                        day=tomorrow.day, hour=0, minute=0, second=0)
    return (midnight - dt_obj).seconds
nsm_list = []
energy["nsm"] = ""
energy.head()
for index, row in energy.iterrows():
    dt_str = row["date"]
    dt_obj = datetime.strptime(dt_str, '%Y-%m-%d %H:%M:%S')
    nsm_list.append(nsm(dt_obj))
# energy["nsm"] = nsm_list

# %%
# energy.drop(["rv1","rv2","date"], axis=1, inplace=True)
energy.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4 ...    RH_9     T_out  Press_mm_hg  RH_out  \
# 0  19.79  44.730000  19.000000 ...   45.53  6.600000        733.5    92.0
# 1  19.79  44.790000  19.000000 ...   45.56  6.483333        733.6    92.0
# 2  19.79  44.933333  18.926667 ...   45.50  6.366667        733.7    92.0
# 3  19.79  45.000000  18.890000 ...   45.40  6.250000        733.8    92.0
# 4  19.79  45.000000  18.890000 ...   45.40  6.133333        733.9    92.0
#
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

energy.hist(bins=50, figsize=(20,15))
plt.show()

# %%
energy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19735 entries, 0 to 19734
# Data columns (total 30 columns):
# date           19735 non-null object
# Appliances     19735 non-null int64
# lights         19735 non-null int64
# T1             19735 non-null float64
# RH_1           19735 non-null float64
# T2             19735 non-null float64
# RH_2           19735 non-null float64
# T3             19735 non-null float64
# RH_3           19735 non-null float64
# T4             19735 non-null float64
# RH_4           19735 non-null float64
# T5             19735 non-null float64
# RH_5           19735 non-null float64
# T6             19735 non-null float64
# RH_6           19735 non-null float64
# T7             19735 non-null float64
# RH_7           19735 non-null float64
# T8             19735 non-null float64
# RH_8           19735 non-null float64
# T9             19735 non-null float64
# RH_9           19735 non-null float64
# T_out          19735 non-null float64
# ...

# %%
energy.describe()
# Out:
#          Appliances        lights            T1          RH_1            T2  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      97.694958      3.801875     21.686571     40.259739     20.341219
# std      102.524891      7.935988      1.606066      3.979299      2.192974
# min       10.000000      0.000000     16.790000     27.023333     16.100000
# 25%       50.000000      0.000000     20.760000     37.333333     18.790000
# 50%       60.000000      0.000000     21.600000     39.656667     20.000000
# 75%      100.000000      0.000000     22.600000     43.066667     21.500000
# max     1080.000000     70.000000     26.260000     63.360000     29.856667
#
#                RH_2            T3          RH_3            T4          RH_4  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      40.420420     22.267611     39.242500     20.855335     39.026904
# ...

# %%
from sklearn.model_selection import train_test_split

train_set, test_set = train_test_split(energy, test_size=0.2, random_state=42)

# %%
energy = train_set.copy()

# %%
corr_matrix = energy.corr()
corr_matrix["Appliances"].sort_values(ascending=False)
# Out:
# Appliances     1.000000
# lights         0.190956
# T2             0.120696
# T6             0.119330
# T_out          0.099980
# RH_1           0.087865
# Windspeed      0.085713
# T3             0.084718
# T1             0.054174
# T4             0.039337
# T8             0.037573
# RH_3           0.035119
# T7             0.026480
# T5             0.018722
# Tdewpoint      0.017963
# RH_4           0.017897
# T9             0.011414
# RH_5           0.009179
# Visibility     0.001954
# rv2           -0.007060
# rv1           -0.007060
# Press_mm_hg   -0.034295
# RH_9          -0.050205
# RH_7          -0.053805
# RH_2          -0.059208
# RH_6          -0.082093
# RH_8          -0.092138
# RH_out        -0.150458
# Name: Appliances, dtype: float64

# %%
energy = train_set.drop("Appliances", axis=1)
energy_label = train_set["Appliances"].copy()

# %%
from sklearn.base import BaseEstimator, TransformerMixin

def nsm(dt_obj):
    """Get the number of seconds until midnight."""
    tomorrow = dt_obj + timedelta(1)
    midnight = datetime(year=tomorrow.year, month=tomorrow.month, 
                        day=tomorrow.day, hour=0, minute=0, second=0)
    return (midnight - dt_obj).seconds

class CombineAttributesAdder(BaseEstimator, TransformerMixin):
    def __init__(self, add_nsm=True):
        self.add_nsm = add_nsm
        
    def fit(self, X, y=None):
        return self
    
    def transform(self, X, y=None):
        for index, row in energy.iterrows():
            dt_str = row["date"]
            dt_obj = datetime.strptime(dt_str, '%Y-%m-%d %H:%M:%S')
            nsm_list.append(nsm(dt_obj))
        print(len(X), len(nsm_list))
        return np.c_[X, nsm_list]
attr_adder = CombineAttributesAdder()
energy_extra_attr = attr_adder.transform(energy.values)
print(energy_extra_attr)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-b9e642ffbb9c> in <module>()
#      22         return np.c_[X, nsm_list]
#      23 attr_adder = CombineAttributesAdder()
# ---> 24 energy_extra_attr = attr_adder.transform(energy.values)
#      25 print(energy_extra_attr)
#
# <ipython-input-15-b9e642ffbb9c> in transform(self, X, y)
#      20             dt_obj = datetime.strptime(dt_str, '%Y-%m-%d %H:%M:%S')
#      21             nsm_list.append(nsm(dt_obj))
# ---> 22         return np.c_[X, nsm_list]
#      23 attr_adder = CombineAttributesAdder()
#      24 energy_extra_attr = attr_adder.transform(energy.values)
#
# c:\users\user\appdata\local\programs\python\python36\lib\site-packages\numpy\lib\index_tricks.py in __getitem__(self, key)
#     338                 objs[k] = objs[k].astype(final_dtype)
#     339
# ...
